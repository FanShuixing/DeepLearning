# %% [markdown]
# #### FCN_VGG16_8s
# #### dataset: pascal voc 2012 segmentation(21分类)
#
# need:
# 1. BilinearUpSampling.py
# 2. [vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5](https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5)

# %%
from keras.layers import *
from keras.regularizers import *
import os
from keras.models import Model
from BilinearUpSampling import *

def FCN_Vgg16_8s(input_shape=None, weight_decay=0., batch_momentum=0.9, batch_shape=None, classes=21):
    if batch_shape:
        img_input = Input(batch_shape=batch_shape)
        image_size = batch_shape[1:3]
    else:
        img_input = Input(shape=input_shape)
        image_size = input_shape[0:2]
    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', kernel_regularizer=l2(weight_decay))(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)
    o_3 = Conv2D(classes, (1, 1), kernel_initializer='zeros', name='conv8s',activation='linear', padding='valid', strides=(1, 1), kernel_regularizer=l2(weight_decay))(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)
    o = Conv2D(classes, (1, 1), kernel_initializer='zeros', name='conv_16s',activation='linear', padding='valid', strides=(1, 1), kernel_regularizer=l2(weight_decay))(x)
#     o=x
    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    # Convolutional layers transfered from fully-connected layers
    x = Conv2D(4096, (7, 7), activation='relu', padding='same', name='fc1', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    x = Conv2D(4096, (1, 1), activation='relu', padding='same', name='fc2', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
#     x = Conv2D(classes, (1, 1), activation='relu', padding='same', name='fc3', kernel_regularizer=l2(weight_decay))(x)

    #classifying layer
    x = Conv2D(classes, (1, 1), kernel_initializer='zeros', activation='linear', padding='valid', strides=(1, 1), kernel_regularizer=l2(weight_decay))(x)

    x = BilinearUpSampling2D(size=(2, 2))(x)
#     x_o=BilinearUpSampling2D(size=(16,16))(o)
#     x=x+o
    x=add([x,o])
#     x = Conv2D(classes, (1, 1), kernel_initializer='he_normal', activation='linear', padding='valid', strides=(1, 1), kernel_regularizer=l2(weight_decay))(x)

    x=BilinearUpSampling2D(size=(2,2))(x)
    x=add([x,o_3])
    x=BilinearUpSampling2D(size=(8,8))(x)

    x=(Activation('softmax'))(x)
    model = Model(img_input, x)
    weights_path='./vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

    model.load_weights(weights_path, by_name=True)
    return model
# Out:
# Using TensorFlow backend.

# %%
from keras import optimizers

model=FCN_Vgg16_8s(input_shape=(320,320,3),classes=21)
optimizer=optimizers.RMSprop(lr=1e-5)
# loss_fn=softmax_sparse_crossentropy_ignoring_last_label
# metrics=[sparse_accuracy_ignoring_last_label]
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['acc'])
# model.compile(loss=loss_fn,optimizer=optimizer,metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 320, 320, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 320, 320, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 160, 160, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 160, 160, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 160, 160, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 80, 80, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 80, 80, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 80, 80, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 80, 80, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 40, 40, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 40, 40, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 40, 40, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 40, 40, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 20, 20, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 20, 20, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 20, 20, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 20, 20, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 10, 10, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# fc1 (Conv2D)                    (None, 10, 10, 4096) 102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 10, 4096) 0           fc1[0][0]
# __________________________________________________________________________________________________
# fc2 (Conv2D)                    (None, 10, 10, 4096) 16781312    dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 10, 4096) 0           fc2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 21)   86037       dropout_2[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_1 (Bilin (None, 20, 20, 21)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv_16s (Conv2D)               (None, 20, 20, 21)   10773       block4_pool[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 20, 20, 21)   0           bilinear_up_sampling2d_1[0][0]
#                                                                  conv_16s[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_2 (Bilin (None, 40, 40, 21)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv8s (Conv2D)                 (None, 40, 40, 21)   5397        block3_pool[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 40, 40, 21)   0           bilinear_up_sampling2d_2[0][0]
#                                                                  conv8s[0][0]
# __________________________________________________________________________________________________
# bilinear_up_sampling2d_3 (Bilin (None, 320, 320, 21) 0           add_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 320, 320, 21) 0           bilinear_up_sampling2d_3[0][0]
# ==================================================================================================
# Total params: 134,362,751
# Trainable params: 134,362,751
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### 2.处理数据，将mask转化为one_hot形式的向量

# %%
colormap = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0], [0, 0, 128],
            [128, 0, 128], [0, 128, 128], [128, 128, 128], [64, 0, 0], [192, 0, 0],
            [64, 128, 0], [192, 128, 0], [64, 0, 128], [192, 0, 128],
            [64, 128, 128], [192, 128, 128], [0, 64, 0], [128, 64, 0],
            [0, 192, 0], [128, 192, 0], [0, 64, 128]]
cm2lbl = np.zeros(256 ** 3)  # 每个像素点有 0 ~ 255 的选择，RGB 三个通道
for i, cm in enumerate(colormap):
    cm2lbl[(cm[0] * 256 + cm[1]) * 256 + cm[2]] = i  # 建立索引


def image2label(im):
    # 输入三维的mask图片，返回二维的矩阵，对每一个像素进行标记(320,320,3)->(320,320)
    #如[0,0,0]标记为0,[128,0,0]标记为1
    data = np.array(im, dtype='int32')
    idx = (data[:, :, 0] * 256 + data[:, :, 1]) * 256 + data[:, :, 2]
    return np.array(cm2lbl[idx], dtype='int64')


def adjustData(img, mask, num_class):
    # 将mask转换为one_hot形式(320,320)->(320,320,21)
    img, _ = img
    mask, _ = mask
    
    img = img / 255.
    mask_label = np.zeros(mask[:, :, :, 0].shape)
    # 将3通道的mask首先转换为二维的label
    for j in range(mask.shape[0]):
        mask_label[j] = image2label(mask[j])

    mask_one_hot = np.zeros(mask_label.shape + (num_class,))
    # 将二维的label转换为三维的one_hot形式
    for i in range(num_class):
        mask_one_hot[mask_label == i, i] = 1
    mask = mask_one_hot.astype('int32')

    return (img, mask)

# %% [markdown]
# #### 3. 模型训练
# - 1.数据采用的是裁剪后的图片，不是通过原图resize的
# - 2.在用到数据增强的时候，必须得注意要在flow_from_directory中传入相同的seed，这样才能保证mask和原图的像素点依然是对应的

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# train_datagen=ImageDataGenerator()


checkpoint=ModelCheckpoint('./models/lab_03_01_fcn8s_crop.hdf5',monitor='val_acc',save_best_only=True,verbose=1)
def train_generator(data_gen_args):
    train_images_datagen = ImageDataGenerator(**data_gen_args)
    train_masks_datagen = ImageDataGenerator(**data_gen_args)

    train_images_generator=train_images_datagen.flow_from_directory('./data/train',classes=['images'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    train_tasks_generator=train_masks_datagen.flow_from_directory('./data/train',classes=['masks'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    train_generator=zip(train_images_generator,train_tasks_generator)
#         train_generator = zip(image_generator, mask_generator)
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,21)
        yield (img,mask)

def val_generator():
    val_images_datagen = ImageDataGenerator()
    val_masks_datagen = ImageDataGenerator()

    val_images_generator=val_images_datagen.flow_from_directory('./data/validation',classes=['images'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    val_tasks_generator=val_masks_datagen.flow_from_directory('./data/validation',classes=['masks'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    val_generator=zip(val_images_generator,val_tasks_generator)
#         train_generator = zip(image_generator, mask_generator)
    for (img,mask) in val_generator:
        img,mask = adjustData(img,mask,21)
        yield (img,mask)
        
        
    
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    horizontal_flip=True,
                    fill_mode='constant',cval=0)
data_gen_args=dict()
train_generator = train_generator(data_gen_args)
val_generator=val_generator()
history=model.fit_generator(train_generator,steps_per_epoch=116,epochs=50,validation_data=val_generator,validation_steps=15,callbacks=[checkpoint])
# Out:
# Epoch 1/30
# Found 290 images belonging to 1 classes.
# Found 2330 images belonging to 1 classes.
# Found 290 images belonging to 1 classes.
# Found 2330 images belonging to 1 classes.
# 116/116 [==============================] - 133s 1s/step - loss: 1.3976 - acc: 0.7080 - val_loss: 1.1955 - val_acc: 0.6986
#
# Epoch 00001: val_acc improved from -inf to 0.69859, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 2/30
# 116/116 [==============================] - 122s 1s/step - loss: 1.0808 - acc: 0.7171 - val_loss: 0.9680 - val_acc: 0.7247
#
# Epoch 00002: val_acc improved from 0.69859 to 0.72469, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 3/30
# 116/116 [==============================] - 121s 1s/step - loss: 0.9184 - acc: 0.7434 - val_loss: 0.8540 - val_acc: 0.7468
#
# Epoch 00003: val_acc improved from 0.72469 to 0.74680, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 4/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.8255 - acc: 0.7585 - val_loss: 0.8053 - val_acc: 0.7596
#
# Epoch 00004: val_acc improved from 0.74680 to 0.75957, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 5/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.7514 - acc: 0.7743 - val_loss: 0.7151 - val_acc: 0.7822
#
# Epoch 00005: val_acc improved from 0.75957 to 0.78224, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 6/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.6768 - acc: 0.7915 - val_loss: 0.6779 - val_acc: 0.7873
#
# Epoch 00006: val_acc improved from 0.78224 to 0.78731, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 7/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.6119 - acc: 0.8046 - val_loss: 0.7673 - val_acc: 0.7570
#
# Epoch 00007: val_acc did not improve from 0.78731
# Epoch 8/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.5678 - acc: 0.8177 - val_loss: 0.6176 - val_acc: 0.8085
#
# Epoch 00008: val_acc improved from 0.78731 to 0.80853, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 9/30
# 116/116 [==============================] - 121s 1s/step - loss: 0.5273 - acc: 0.8291 - val_loss: 0.7256 - val_acc: 0.7699
#
# Epoch 00009: val_acc did not improve from 0.80853
# Epoch 10/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.4847 - acc: 0.8397 - val_loss: 0.6926 - val_acc: 0.7828
#
# Epoch 00010: val_acc did not improve from 0.80853
# Epoch 11/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.4517 - acc: 0.8491 - val_loss: 0.5788 - val_acc: 0.8124
#
# Epoch 00011: val_acc improved from 0.80853 to 0.81244, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 12/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.4234 - acc: 0.8573 - val_loss: 0.6331 - val_acc: 0.8029
#
# Epoch 00012: val_acc did not improve from 0.81244
# Epoch 13/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.3937 - acc: 0.8675 - val_loss: 0.5392 - val_acc: 0.8247
#
# Epoch 00013: val_acc improved from 0.81244 to 0.82472, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 14/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.3698 - acc: 0.8752 - val_loss: 0.5508 - val_acc: 0.8234
#
# Epoch 00014: val_acc did not improve from 0.82472
# Epoch 15/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.3537 - acc: 0.8777 - val_loss: 0.5296 - val_acc: 0.8276
#
# Epoch 00015: val_acc improved from 0.82472 to 0.82755, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 16/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.3164 - acc: 0.8912 - val_loss: 0.6619 - val_acc: 0.7861
#
# Epoch 00016: val_acc did not improve from 0.82755
# Epoch 17/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.3152 - acc: 0.8898 - val_loss: 0.5693 - val_acc: 0.8140
#
# Epoch 00017: val_acc did not improve from 0.82755
# Epoch 18/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2889 - acc: 0.8997 - val_loss: 0.5593 - val_acc: 0.8207
#
# Epoch 00018: val_acc did not improve from 0.82755
# Epoch 19/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2682 - acc: 0.9071 - val_loss: 0.5704 - val_acc: 0.8298
#
# Epoch 00019: val_acc improved from 0.82755 to 0.82983, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 20/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2589 - acc: 0.9100 - val_loss: 0.5936 - val_acc: 0.8175
#
# Epoch 00020: val_acc did not improve from 0.82983
# Epoch 21/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2432 - acc: 0.9157 - val_loss: 0.5531 - val_acc: 0.8314
#
# Epoch 00021: val_acc improved from 0.82983 to 0.83142, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 22/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2269 - acc: 0.9206 - val_loss: 0.5884 - val_acc: 0.8218
#
# Epoch 00022: val_acc did not improve from 0.83142
# Epoch 23/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2118 - acc: 0.9256 - val_loss: 0.6834 - val_acc: 0.8010
#
# Epoch 00023: val_acc did not improve from 0.83142
# Epoch 24/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.2092 - acc: 0.9257 - val_loss: 0.5709 - val_acc: 0.8418
#
# Epoch 00024: val_acc improved from 0.83142 to 0.84180, saving model to ./models/lab_03_01_fcn8s_crop.hdf5
# Epoch 25/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1927 - acc: 0.9319 - val_loss: 0.6618 - val_acc: 0.7987
#
# Epoch 00025: val_acc did not improve from 0.84180
# Epoch 26/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1843 - acc: 0.9339 - val_loss: 0.6266 - val_acc: 0.8096
#
# Epoch 00026: val_acc did not improve from 0.84180
# Epoch 27/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1753 - acc: 0.9376 - val_loss: 0.6372 - val_acc: 0.8149
#
# Epoch 00027: val_acc did not improve from 0.84180
# Epoch 28/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1721 - acc: 0.9385 - val_loss: 0.6124 - val_acc: 0.8243
#
# Epoch 00028: val_acc did not improve from 0.84180
# Epoch 29/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1644 - acc: 0.9409 - val_loss: 0.6109 - val_acc: 0.8277
#
# Epoch 00029: val_acc did not improve from 0.84180
# Epoch 30/30
# 116/116 [==============================] - 122s 1s/step - loss: 0.1558 - acc: 0.9436 - val_loss: 0.5627 - val_acc: 0.8509
#
# Epoch 00030: val_acc improved from 0.84180 to 0.85093, saving model to ./models/lab_03_01_fcn8s_crop.hdf5

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
