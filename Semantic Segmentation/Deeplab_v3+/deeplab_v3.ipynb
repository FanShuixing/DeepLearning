# %%
from model import Deeplabv3
model=Deeplabv3(weights='pascal_voc',input_shape=(320,320,3),classes=21)
# Out:
# Using TensorFlow backend.

# %%
from keras import optimizers
# model=FCN_Vgg16_32s(input_shape=(320,320,3),classes=21)
optimizer=optimizers.RMSprop(lr=1e-5)
#可以自定义损失函数和metrics
# loss_fn=softmax_sparse_crossentropy_ignoring_last_label
# metrics=[sparse_accuracy_ignoring_last_label]
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['acc'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 160, 160, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# Conv_BN (BatchNormalization)    (None, 160, 160, 32) 128         Conv[0][0]
# __________________________________________________________________________________________________
# Conv_Relu6 (Activation)         (None, 160, 160, 32) 0           Conv_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 160, 160, 32) 288         Conv_Relu6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 160, 160, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (A (None, 160, 160, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 160, 160, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 160, 160, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand (Conv2D) (None, 160, 160, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_BN (Batc (None, 160, 160, 96) 384         expanded_conv_1_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_relu (Ac (None, 160, 160, 96) 0           expanded_conv_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise (Dept (None, 80, 80, 96)   864         expanded_conv_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_BN (B (None, 80, 80, 96)   384         expanded_conv_1_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_relu  (None, 80, 80, 96)   0           expanded_conv_1_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_1_project (Conv2D (None, 80, 80, 24)   2304        expanded_conv_1_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_1_project_BN (Bat (None, 80, 80, 24)   96          expanded_conv_1_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand (Conv2D) (None, 80, 80, 144)  3456        expanded_conv_1_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_BN (Batc (None, 80, 80, 144)  576         expanded_conv_2_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_relu (Ac (None, 80, 80, 144)  0           expanded_conv_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise (Dept (None, 80, 80, 144)  1296        expanded_conv_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_BN (B (None, 80, 80, 144)  576         expanded_conv_2_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_relu  (None, 80, 80, 144)  0           expanded_conv_2_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_2_project (Conv2D (None, 80, 80, 24)   3456        expanded_conv_2_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_2_project_BN (Bat (None, 80, 80, 24)   96          expanded_conv_2_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_add (Add)       (None, 80, 80, 24)   0           expanded_conv_1_project_BN[0][0]
#                                                                  expanded_conv_2_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand (Conv2D) (None, 80, 80, 144)  3456        expanded_conv_2_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_BN (Batc (None, 80, 80, 144)  576         expanded_conv_3_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_relu (Ac (None, 80, 80, 144)  0           expanded_conv_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise (Dept (None, 40, 40, 144)  1296        expanded_conv_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_BN (B (None, 40, 40, 144)  576         expanded_conv_3_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_relu  (None, 40, 40, 144)  0           expanded_conv_3_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_3_project (Conv2D (None, 40, 40, 32)   4608        expanded_conv_3_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_3_project_BN (Bat (None, 40, 40, 32)   128         expanded_conv_3_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand (Conv2D) (None, 40, 40, 192)  6144        expanded_conv_3_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_BN (Batc (None, 40, 40, 192)  768         expanded_conv_4_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_relu (Ac (None, 40, 40, 192)  0           expanded_conv_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise (Dept (None, 40, 40, 192)  1728        expanded_conv_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_BN (B (None, 40, 40, 192)  768         expanded_conv_4_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_relu  (None, 40, 40, 192)  0           expanded_conv_4_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_4_project (Conv2D (None, 40, 40, 32)   6144        expanded_conv_4_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_4_project_BN (Bat (None, 40, 40, 32)   128         expanded_conv_4_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_add (Add)       (None, 40, 40, 32)   0           expanded_conv_3_project_BN[0][0]
#                                                                  expanded_conv_4_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand (Conv2D) (None, 40, 40, 192)  6144        expanded_conv_4_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_BN (Batc (None, 40, 40, 192)  768         expanded_conv_5_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_relu (Ac (None, 40, 40, 192)  0           expanded_conv_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise (Dept (None, 40, 40, 192)  1728        expanded_conv_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_BN (B (None, 40, 40, 192)  768         expanded_conv_5_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_relu  (None, 40, 40, 192)  0           expanded_conv_5_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_5_project (Conv2D (None, 40, 40, 32)   6144        expanded_conv_5_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_5_project_BN (Bat (None, 40, 40, 32)   128         expanded_conv_5_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_add (Add)       (None, 40, 40, 32)   0           expanded_conv_4_add[0][0]
#                                                                  expanded_conv_5_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand (Conv2D) (None, 40, 40, 192)  6144        expanded_conv_5_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_BN (Batc (None, 40, 40, 192)  768         expanded_conv_6_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_relu (Ac (None, 40, 40, 192)  0           expanded_conv_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise (Dept (None, 40, 40, 192)  1728        expanded_conv_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_BN (B (None, 40, 40, 192)  768         expanded_conv_6_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_relu  (None, 40, 40, 192)  0           expanded_conv_6_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_6_project (Conv2D (None, 40, 40, 64)   12288       expanded_conv_6_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_6_project_BN (Bat (None, 40, 40, 64)   256         expanded_conv_6_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand (Conv2D) (None, 40, 40, 384)  24576       expanded_conv_6_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_BN (Batc (None, 40, 40, 384)  1536        expanded_conv_7_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_relu (Ac (None, 40, 40, 384)  0           expanded_conv_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise (Dept (None, 40, 40, 384)  3456        expanded_conv_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_BN (B (None, 40, 40, 384)  1536        expanded_conv_7_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_relu  (None, 40, 40, 384)  0           expanded_conv_7_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_7_project (Conv2D (None, 40, 40, 64)   24576       expanded_conv_7_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_7_project_BN (Bat (None, 40, 40, 64)   256         expanded_conv_7_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_add (Add)       (None, 40, 40, 64)   0           expanded_conv_6_project_BN[0][0]
#                                                                  expanded_conv_7_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand (Conv2D) (None, 40, 40, 384)  24576       expanded_conv_7_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_BN (Batc (None, 40, 40, 384)  1536        expanded_conv_8_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_relu (Ac (None, 40, 40, 384)  0           expanded_conv_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise (Dept (None, 40, 40, 384)  3456        expanded_conv_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_BN (B (None, 40, 40, 384)  1536        expanded_conv_8_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_relu  (None, 40, 40, 384)  0           expanded_conv_8_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_8_project (Conv2D (None, 40, 40, 64)   24576       expanded_conv_8_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_8_project_BN (Bat (None, 40, 40, 64)   256         expanded_conv_8_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_add (Add)       (None, 40, 40, 64)   0           expanded_conv_7_add[0][0]
#                                                                  expanded_conv_8_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand (Conv2D) (None, 40, 40, 384)  24576       expanded_conv_8_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_BN (Batc (None, 40, 40, 384)  1536        expanded_conv_9_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_relu (Ac (None, 40, 40, 384)  0           expanded_conv_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise (Dept (None, 40, 40, 384)  3456        expanded_conv_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_BN (B (None, 40, 40, 384)  1536        expanded_conv_9_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_relu  (None, 40, 40, 384)  0           expanded_conv_9_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_9_project (Conv2D (None, 40, 40, 64)   24576       expanded_conv_9_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_9_project_BN (Bat (None, 40, 40, 64)   256         expanded_conv_9_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_add (Add)       (None, 40, 40, 64)   0           expanded_conv_8_add[0][0]
#                                                                  expanded_conv_9_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand (Conv2D (None, 40, 40, 384)  24576       expanded_conv_9_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_BN (Bat (None, 40, 40, 384)  1536        expanded_conv_10_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_relu (A (None, 40, 40, 384)  0           expanded_conv_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise (Dep (None, 40, 40, 384)  3456        expanded_conv_10_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_BN ( (None, 40, 40, 384)  1536        expanded_conv_10_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_relu (None, 40, 40, 384)  0           expanded_conv_10_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_10_project (Conv2 (None, 40, 40, 96)   36864       expanded_conv_10_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_10_project_BN (Ba (None, 40, 40, 96)   384         expanded_conv_10_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand (Conv2D (None, 40, 40, 576)  55296       expanded_conv_10_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_BN (Bat (None, 40, 40, 576)  2304        expanded_conv_11_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_relu (A (None, 40, 40, 576)  0           expanded_conv_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise (Dep (None, 40, 40, 576)  5184        expanded_conv_11_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_BN ( (None, 40, 40, 576)  2304        expanded_conv_11_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_relu (None, 40, 40, 576)  0           expanded_conv_11_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_11_project (Conv2 (None, 40, 40, 96)   55296       expanded_conv_11_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_11_project_BN (Ba (None, 40, 40, 96)   384         expanded_conv_11_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_add (Add)      (None, 40, 40, 96)   0           expanded_conv_10_project_BN[0][0]
#                                                                  expanded_conv_11_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand (Conv2D (None, 40, 40, 576)  55296       expanded_conv_11_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_BN (Bat (None, 40, 40, 576)  2304        expanded_conv_12_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_relu (A (None, 40, 40, 576)  0           expanded_conv_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise (Dep (None, 40, 40, 576)  5184        expanded_conv_12_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_BN ( (None, 40, 40, 576)  2304        expanded_conv_12_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_relu (None, 40, 40, 576)  0           expanded_conv_12_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_12_project (Conv2 (None, 40, 40, 96)   55296       expanded_conv_12_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_12_project_BN (Ba (None, 40, 40, 96)   384         expanded_conv_12_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_add (Add)      (None, 40, 40, 96)   0           expanded_conv_11_add[0][0]
#                                                                  expanded_conv_12_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand (Conv2D (None, 40, 40, 576)  55296       expanded_conv_12_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_BN (Bat (None, 40, 40, 576)  2304        expanded_conv_13_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_relu (A (None, 40, 40, 576)  0           expanded_conv_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise (Dep (None, 40, 40, 576)  5184        expanded_conv_13_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_BN ( (None, 40, 40, 576)  2304        expanded_conv_13_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_relu (None, 40, 40, 576)  0           expanded_conv_13_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_13_project (Conv2 (None, 40, 40, 160)  92160       expanded_conv_13_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_13_project_BN (Ba (None, 40, 40, 160)  640         expanded_conv_13_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand (Conv2D (None, 40, 40, 960)  153600      expanded_conv_13_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_BN (Bat (None, 40, 40, 960)  3840        expanded_conv_14_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_relu (A (None, 40, 40, 960)  0           expanded_conv_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise (Dep (None, 40, 40, 960)  8640        expanded_conv_14_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_BN ( (None, 40, 40, 960)  3840        expanded_conv_14_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_relu (None, 40, 40, 960)  0           expanded_conv_14_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_14_project (Conv2 (None, 40, 40, 160)  153600      expanded_conv_14_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_14_project_BN (Ba (None, 40, 40, 160)  640         expanded_conv_14_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_add (Add)      (None, 40, 40, 160)  0           expanded_conv_13_project_BN[0][0]
#                                                                  expanded_conv_14_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand (Conv2D (None, 40, 40, 960)  153600      expanded_conv_14_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_BN (Bat (None, 40, 40, 960)  3840        expanded_conv_15_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_relu (A (None, 40, 40, 960)  0           expanded_conv_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise (Dep (None, 40, 40, 960)  8640        expanded_conv_15_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_BN ( (None, 40, 40, 960)  3840        expanded_conv_15_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_relu (None, 40, 40, 960)  0           expanded_conv_15_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_15_project (Conv2 (None, 40, 40, 160)  153600      expanded_conv_15_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_15_project_BN (Ba (None, 40, 40, 160)  640         expanded_conv_15_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_add (Add)      (None, 40, 40, 160)  0           expanded_conv_14_add[0][0]
#                                                                  expanded_conv_15_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand (Conv2D (None, 40, 40, 960)  153600      expanded_conv_15_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_BN (Bat (None, 40, 40, 960)  3840        expanded_conv_16_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_relu (A (None, 40, 40, 960)  0           expanded_conv_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise (Dep (None, 40, 40, 960)  8640        expanded_conv_16_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_BN ( (None, 40, 40, 960)  3840        expanded_conv_16_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_relu (None, 40, 40, 960)  0           expanded_conv_16_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_16_project (Conv2 (None, 40, 40, 320)  307200      expanded_conv_16_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_16_project_BN (Ba (None, 40, 40, 320)  1280        expanded_conv_16_project[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 320)    0           expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    81920       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 40, 40, 256)  81920       expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 40, 40, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 40, 40, 256)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 40, 40, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 40, 40, 512)  0           bilinear_upsampling_1[0][0]
#                                                                  aspp0_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 40, 40, 256)  131072      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 40, 40, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 40, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 40, 40, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# logits_semantic (Conv2D)        (None, 40, 40, 21)   5397        dropout_1[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_2 (Bilinear (None, 320, 320, 21) 0           logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 320, 320, 21) 0           bilinear_upsampling_2[0][0]
# ==================================================================================================
# Total params: 2,146,645
# Trainable params: 2,113,557
# Non-trainable params: 33,088
# __________________________________________________________________________________________________

# %%
import numpy as np
colormap = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0], [0, 0, 128],
            [128, 0, 128], [0, 128, 128], [128, 128, 128], [64, 0, 0], [192, 0, 0],
            [64, 128, 0], [192, 128, 0], [64, 0, 128], [192, 0, 128],
            [64, 128, 128], [192, 128, 128], [0, 64, 0], [128, 64, 0],
            [0, 192, 0], [128, 192, 0], [0, 64, 128]]
cm2lbl = np.zeros(256 ** 3)  # 每个像素点有 0 ~ 255 的选择，RGB 三个通道
for i, cm in enumerate(colormap):
    cm2lbl[(cm[0] * 256 + cm[1]) * 256 + cm[2]] = i  # 建立索引


def image2label(im):
    # 输入三维的mask图片，返回二维的矩阵，对每一个像素进行标记(320,320,3)->(320,320)
    #如[0,0,0]标记为0,[128,0,0]标记为1
    data = np.array(im, dtype='int32')
    idx = (data[:, :, 0] * 256 + data[:, :, 1]) * 256 + data[:, :, 2]
    return np.array(cm2lbl[idx], dtype='int64')


def adjustData(img, mask, num_class):
    # 将mask转换为one_hot形式(320,320)->(320,320,21)
    img, _ = img
    mask, _ = mask
    
    img = img / 255.
    mask_label = np.zeros(mask[:, :, :, 0].shape)
    # 将3通道的mask首先转换为二维的label
    for j in range(mask.shape[0]):
        mask_label[j] = image2label(mask[j])

    mask_one_hot = np.zeros(mask_label.shape + (num_class,))
    # 将二维的label转换为三维的one_hot形式
    for i in range(num_class):
        mask_one_hot[mask_label == i, i] = 1
    mask = mask_one_hot.astype('int32')
    return (img, mask)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# train_datagen=ImageDataGenerator()

checkpoint=ModelCheckpoint('./models/lab_01_deeplab_v3.hdf5',monitor='val_acc',save_best_only=True,verbose=1)
def train_generator(data_gen_args):
    train_images_datagen = ImageDataGenerator(**data_gen_args)
    train_masks_datagen = ImageDataGenerator(**data_gen_args)

    train_images_generator=train_images_datagen.flow_from_directory('/input0/pascal_2012_seg/train',classes=['images'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    train_tasks_generator=train_masks_datagen.flow_from_directory('/input0/pascal_2012_seg/train',classes=['masks'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    train_generator=zip(train_images_generator,train_tasks_generator)

    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,21)
        yield (img,mask)

def val_generator():
    val_images_datagen = ImageDataGenerator()
    val_masks_datagen = ImageDataGenerator()

    val_images_generator=val_images_datagen.flow_from_directory('/input0/pascal_2012_seg/validation',classes=['images'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    val_tasks_generator=val_masks_datagen.flow_from_directory('/input0/pascal_2012_seg/validation',classes=['masks'],class_mode='categorical',seed=1,target_size=(320,320),batch_size=20)
    val_generator=zip(val_images_generator,val_tasks_generator)
    for (img,mask) in val_generator:
        img,mask = adjustData(img,mask,21)
        yield (img,mask)
        

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    horizontal_flip=True,
                    fill_mode='constant',cval=0)
#需要数据增强的时候直接注释掉下一行就行
data_gen_args=dict()
train_generator = train_generator(data_gen_args)
val_generator=val_generator()
history=model.fit_generator(train_generator,steps_per_epoch=120,epochs=30,validation_data=val_generator,validation_steps=15,callbacks=[checkpoint])
# Out:
# Epoch 1/30
# Found 2330 images belonging to 1 classes.
# Found 290 images belonging to 1 classes.
# Found 2330 images belonging to 1 classes.
# Found 290 images belonging to 1 classes.
# 120/120 [==============================] - 136s 1s/step - loss: 0.2558 - acc: 0.9087 - val_loss: 0.2589 - val_acc: 0.9076
#
# Epoch 00001: val_acc improved from -inf to 0.90758, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 2/30
# 120/120 [==============================] - 110s 920ms/step - loss: 0.2124 - acc: 0.9224 - val_loss: 0.2371 - val_acc: 0.9155
#
# Epoch 00002: val_acc improved from 0.90758 to 0.91549, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 3/30
# 120/120 [==============================] - 119s 995ms/step - loss: 0.1975 - acc: 0.9282 - val_loss: 0.2279 - val_acc: 0.9186
#
# Epoch 00003: val_acc improved from 0.91549 to 0.91863, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 4/30
# 120/120 [==============================] - 115s 955ms/step - loss: 0.1878 - acc: 0.9319 - val_loss: 0.2253 - val_acc: 0.9199
#
# Epoch 00004: val_acc improved from 0.91863 to 0.91989, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 5/30
# 120/120 [==============================] - 121s 1s/step - loss: 0.1759 - acc: 0.9357 - val_loss: 0.2189 - val_acc: 0.9218
#
# Epoch 00005: val_acc improved from 0.91989 to 0.92177, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 6/30
# 120/120 [==============================] - 120s 1s/step - loss: 0.1689 - acc: 0.9377 - val_loss: 0.2156 - val_acc: 0.9225
#
# Epoch 00006: val_acc improved from 0.92177 to 0.92249, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 7/30
# 120/120 [==============================] - 118s 982ms/step - loss: 0.1635 - acc: 0.9401 - val_loss: 0.2174 - val_acc: 0.9221
#
# Epoch 00007: val_acc did not improve from 0.92249
# Epoch 8/30
# 120/120 [==============================] - 118s 987ms/step - loss: 0.1581 - acc: 0.9413 - val_loss: 0.2182 - val_acc: 0.9233
#
# Epoch 00008: val_acc improved from 0.92249 to 0.92327, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 9/30
# 120/120 [==============================] - 115s 957ms/step - loss: 0.1537 - acc: 0.9437 - val_loss: 0.2158 - val_acc: 0.9243
#
# Epoch 00009: val_acc improved from 0.92327 to 0.92435, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 10/30
# 120/120 [==============================] - 120s 1s/step - loss: 0.1518 - acc: 0.9437 - val_loss: 0.2148 - val_acc: 0.9243
#
# Epoch 00010: val_acc did not improve from 0.92435
# Epoch 11/30
# 120/120 [==============================] - 117s 979ms/step - loss: 0.1471 - acc: 0.9452 - val_loss: 0.2128 - val_acc: 0.9251
#
# Epoch 00011: val_acc improved from 0.92435 to 0.92509, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 12/30
# 120/120 [==============================] - 122s 1s/step - loss: 0.1403 - acc: 0.9474 - val_loss: 0.2120 - val_acc: 0.9256
#
# Epoch 00012: val_acc improved from 0.92509 to 0.92559, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 13/30
# 120/120 [==============================] - 122s 1s/step - loss: 0.1444 - acc: 0.9457 - val_loss: 0.2133 - val_acc: 0.9252
#
# Epoch 00013: val_acc did not improve from 0.92559
# Epoch 14/30
# 120/120 [==============================] - 121s 1s/step - loss: 0.1380 - acc: 0.9485 - val_loss: 0.2161 - val_acc: 0.9257
#
# Epoch 00014: val_acc improved from 0.92559 to 0.92574, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 15/30
# 120/120 [==============================] - 117s 975ms/step - loss: 0.1329 - acc: 0.9501 - val_loss: 0.2161 - val_acc: 0.9255
#
# Epoch 00015: val_acc did not improve from 0.92574
# Epoch 16/30
# 120/120 [==============================] - 115s 962ms/step - loss: 0.1338 - acc: 0.9493 - val_loss: 0.2176 - val_acc: 0.9248
#
# Epoch 00016: val_acc did not improve from 0.92574
# Epoch 17/30
# 120/120 [==============================] - 121s 1s/step - loss: 0.1327 - acc: 0.9498 - val_loss: 0.2151 - val_acc: 0.9251
#
# Epoch 00017: val_acc did not improve from 0.92574
# Epoch 18/30
# 120/120 [==============================] - 118s 981ms/step - loss: 0.1277 - acc: 0.9515 - val_loss: 0.2179 - val_acc: 0.9255
#
# Epoch 00018: val_acc did not improve from 0.92574
# Epoch 19/30
# 120/120 [==============================] - 119s 991ms/step - loss: 0.1272 - acc: 0.9518 - val_loss: 0.2192 - val_acc: 0.9249
#
# Epoch 00019: val_acc did not improve from 0.92574
# Epoch 20/30
# 120/120 [==============================] - 119s 991ms/step - loss: 0.1266 - acc: 0.9517 - val_loss: 0.2176 - val_acc: 0.9257
#
# Epoch 00020: val_acc did not improve from 0.92574
# Epoch 21/30
# 120/120 [==============================] - 112s 937ms/step - loss: 0.1235 - acc: 0.9529 - val_loss: 0.2191 - val_acc: 0.9255
#
# Epoch 00021: val_acc did not improve from 0.92574
# Epoch 22/30
# 120/120 [==============================] - 116s 968ms/step - loss: 0.1198 - acc: 0.9545 - val_loss: 0.2193 - val_acc: 0.9259
#
# Epoch 00022: val_acc improved from 0.92574 to 0.92591, saving model to ./models/lab_01_deeplab_v3.hdf5
# Epoch 23/30
# 120/120 [==============================] - 121s 1s/step - loss: 0.1210 - acc: 0.9539 - val_loss: 0.2187 - val_acc: 0.9259
#
# Epoch 00023: val_acc did not improve from 0.92591
# Epoch 24/30
# 120/120 [==============================] - 122s 1s/step - loss: 0.1190 - acc: 0.9546 - val_loss: 0.2206 - val_acc: 0.9259
#
# Epoch 00024: val_acc did not improve from 0.92591
# Epoch 25/30
# 120/120 [==============================] - 119s 992ms/step - loss: 0.1187 - acc: 0.9548 - val_loss: 0.2193 - val_acc: 0.9254
#
# Epoch 00025: val_acc did not improve from 0.92591
# Epoch 26/30
# 120/120 [==============================] - 121s 1s/step - loss: 0.1132 - acc: 0.9566 - val_loss: 0.2177 - val_acc: 0.9255
#
# Epoch 00026: val_acc did not improve from 0.92591
# Epoch 27/30
# 120/120 [==============================] - 117s 975ms/step - loss: 0.1148 - acc: 0.9559 - val_loss: 0.2175 - val_acc: 0.9258
#
# Epoch 00027: val_acc did not improve from 0.92591
# Epoch 28/30
# 120/120 [==============================] - 118s 981ms/step - loss: 0.1148 - acc: 0.9558 - val_loss: 0.2237 - val_acc: 0.9253
#
# Epoch 00028: val_acc did not improve from 0.92591
# Epoch 29/30
# 120/120 [==============================] - 119s 993ms/step - loss: 0.1113 - acc: 0.9572 - val_loss: 0.2245 - val_acc: 0.9248
#
# Epoch 00029: val_acc did not improve from 0.92591
# Epoch 30/30
# 120/120 [==============================] - 119s 990ms/step - loss: 0.1111 - acc: 0.9572 - val_loss: 0.2238 - val_acc: 0.9251
#
# Epoch 00030: val_acc did not improve from 0.92591
