# %%
from model import Deeplabv3
from keras.callbacks import ModelCheckpoint
import numpy as np
import os,csv
from keras.preprocessing import image
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
colormap =[[0, 0, 0],
 [15, 15, 15],
 [16, 16, 16],
 [17, 17, 17],
 [18, 18, 18],
 [21, 21, 21],
 [23, 23, 23],
 [24, 24, 24],
 [30, 30, 30],
 [41, 41, 41],
 [42, 42, 42],
 [43, 43, 43],
 [45, 45, 45],
 [46, 46, 46],
 [47, 47, 47],
 [49, 49, 49],
 [50, 50, 50],
 [54, 54, 54],
 [56, 56, 56],
 [62, 62, 62],
 [65, 65, 65],
 [90, 90, 90],
 [255, 255, 255]]

cm2lbl = np.zeros(256 ** 3)  # 每个像素点有 0 ~ 255 的选择，RGB 三个通道
for i, cm in enumerate(colormap):
    cm2lbl[(cm[0] * 256 + cm[1]) * 256 + cm[2]] = i  # 建立索引

    
def image2label(im):
    # 输入三维的mask图片，返回二维的矩阵，对每一个像素进行标记(320,320,3)->(320,320)
    #如[0,0,0]标记为0,[128,0,0]标记为1
    data = np.array(im, dtype='int32')
    idx = (data[:, :, 0] * 256 + data[:, :, 1]) * 256 + data[:, :, 2]
    return np.array(cm2lbl[idx], dtype='int64')

# %%
def generateData(batch_size,train=True,root_dir='/input0/land_23_jpg'):
    '''
    输入的是整个数据的images和masks，以及每次训练的batch_size数目，返回的是经过数据增强的batch_size批次大小的数组.
    其中mask的维度为(None,224,224),每次读取batch_size大小的images和masks时，做了(None,224,224)->(None,224,224,23)
    的转化，然后再做了数据增强。
    '''

    fr=open('%s/meta.csv'%root_dir)
    all_list=[]
    reader=csv.reader(fr)
    for each in reader:
        all_list.append(each)
    all_list=all_list[1:]
    train_num=int(len(all_list)*0.9)
    if train:
#         train_list = all_list[:train_num]
        train_list=all_list
    else:
        #         train_num=int(len(all_list)*0.1)
        train_list = all_list[train_num:]
    while True:
        train_data = []
        train_label = []
        batch = 0
        for each in train_list:
            batch += 1
            img = image.load_img('%s/%s' % (root_dir, each[1]))
            img = image.img_to_array(img)
            img=img/255.
            label = image.load_img('%s/%s' % (root_dir, each[0]))
            label = image.img_to_array(label)
            train_data.append(img)
            train_label.append(label)
            if batch % batch_size == 0:
                train_data = np.array(train_data)
                train_label = np.array(train_label)
                mask_label = np.zeros(train_label[:, :, :, 0].shape)

                for j in range(train_label.shape[0]):
                    mask_label[j] = image2label(train_label[j])
                mask_one_hot = np.zeros(mask_label.shape + (23,))
                for i in range(23):
                    mask_one_hot[mask_label == i, i] = 1
                train_label = mask_one_hot.astype('int32')
                yield (train_data, train_label)

                train_data = []
                train_label = []
                batch = 0

# %%
model = Deeplabv3(weights=None, input_shape=(224, 224, 3), classes=23, backbone='xception')
optimizer = optimizers.RMSprop(lr=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
if not os.path.exists('./models'):
    os.mkdir('./models')
checkpoint = ModelCheckpoint('./models/deeplab_2.hdf5', monitor='acc', save_best_only=True, verbose=1)

model.load_weights('./models/deeplab.hdf5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# entry_flow_conv1_1 (Conv2D)     (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_1_BN (BatchNor (None, 112, 112, 32) 128         entry_flow_conv1_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 32) 0           entry_flow_conv1_1_BN[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2 (Conv2D)     (None, 112, 112, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2_BN (BatchNor (None, 112, 112, 64) 256         entry_flow_conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 64) 0           entry_flow_conv1_2_BN[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 64) 576         activation_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 64) 256         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 8192        entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 512         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 128 0           entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 1152        activation_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 16384       entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 112, 112, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 128 0           entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 114, 114, 128 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 56, 56, 128)  1152        activation_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 56, 56, 128)  512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 112, 112, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 56, 56, 128)  16384       entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut (Con (None, 56, 56, 128)  8192        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 56, 56, 128)  512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut_BN ( (None, 56, 56, 128)  512         entry_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 128)  0           entry_flow_block1_separable_conv3
#                                                                  entry_flow_block1_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 128)  1152        activation_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 128)  512         entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  32768       entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  1024        entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  2304        activation_7[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  65536       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 56, 56, 256)  1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 58, 58, 256)  0           entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 58, 58, 256)  0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 28, 28, 256)  2304        activation_8[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 28, 28, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 56, 56, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 28, 28, 256)  65536       entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut (Con (None, 28, 28, 256)  32768       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 28, 28, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut_BN ( (None, 28, 28, 256)  1024        entry_flow_block2_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 256)  0           entry_flow_block2_separable_conv3
#                                                                  entry_flow_block2_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 256)  2304        activation_9[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 256)  1024        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  186368      entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  2912        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 728)  0           entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  6552        activation_10[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  529984      entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 28, 28, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 30, 30, 728)  0           entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 30, 728)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 14, 14, 728)  6552        activation_11[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 14, 14, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 28, 28, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 14, 14, 728)  529984      entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut (Con (None, 14, 14, 728)  186368      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 14, 14, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut_BN ( (None, 14, 14, 728)  2912        entry_flow_block3_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 728)  0           entry_flow_block3_separable_conv3
#                                                                  entry_flow_block3_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  6552        activation_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  6552        activation_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  6552        activation_14[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_1_separable_conv
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 14, 14, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  6552        activation_15[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  6552        activation_16[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  6552        activation_17[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_2_separable_conv
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  6552        activation_18[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  6552        activation_19[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  6552        activation_20[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_3_separable_conv
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  6552        activation_21[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  6552        activation_22[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  6552        activation_23[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_4_separable_conv
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  6552        activation_24[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  6552        activation_25[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  6552        activation_26[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_5_separable_conv
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  6552        activation_27[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  6552        activation_28[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  6552        activation_29[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 728)  0           middle_flow_unit_6_separable_conv
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  6552        activation_30[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  6552        activation_31[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  6552        activation_32[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 728)  0           middle_flow_unit_7_separable_conv
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  6552        activation_33[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  6552        activation_34[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  6552        activation_35[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 728)  0           middle_flow_unit_8_separable_conv
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  6552        activation_36[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  6552        activation_37[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  6552        activation_38[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 14, 14, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 728)  0           middle_flow_unit_9_separable_conv
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 728)  0           add_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  6552        activation_39[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  6552        activation_40[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  6552        activation_41[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 728)  0           middle_flow_unit_10_separable_con
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 728)  0           add_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 14, 14, 728)  6552        activation_42[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 14, 14, 728)  529984      middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 14, 14, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 728)  0           middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 14, 14, 728)  6552        activation_43[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 14, 14, 1024) 9216        activation_62[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 14, 14, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 14, 14, 1024) 1048576     exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut (Conv (None, 14, 14, 1024) 745472      add_19[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 14, 14, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut_BN (B (None, 14, 14, 1024) 4096        exit_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 14, 14, 1024) 0           exit_flow_block1_separable_conv3_
#                                                                  exit_flow_block1_shortcut_BN[0][0
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1024) 9216        add_20[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1024) 4096        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 14, 14, 1024) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 1572864     activation_63[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 6144        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 14, 14, 1536) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 13824       activation_64[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 14, 14, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 2359296     activation_65[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 14, 14, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 13824       activation_66[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 1536) 6144        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 14, 14, 1536) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 2048) 3145728     activation_67[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 14, 14, 2048) 8192        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 14, 14, 2048) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 14, 14, 2048) 18432       activation_68[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 14, 14, 2048) 18432       activation_68[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 14, 14, 2048) 18432       activation_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 2048)   0           activation_68[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 14, 14, 2048) 8192        aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 14, 14, 2048) 8192        aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 14, 14, 2048) 8192        aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    524288      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 14, 14, 2048) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 14, 14, 2048) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 14, 14, 2048) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 14, 14, 256)  524288      activation_68[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 14, 14, 256)  524288      activation_70[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 14, 14, 256)  524288      activation_72[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 14, 14, 256)  524288      activation_74[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 14, 14, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 14, 14, 256)  1024        aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 14, 14, 256)  1024        aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 14, 14, 256)  1024        aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 14, 14, 256)  0           activation_69[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 14, 14, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 14, 14, 256)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 14, 14, 256)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 14, 14, 256)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1280) 0           bilinear_upsampling_1[0][0]
#                                                                  aspp0_activation[0][0]
#                                                                  activation_71[0][0]
#                                                                  activation_73[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 14, 14, 256)  327680      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 14, 14, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 14, 14, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# feature_projection0 (Conv2D)    (None, 56, 56, 48)   12288       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 14, 14, 256)  0           activation_76[0][0]
# __________________________________________________________________________________________________
# feature_projection0_BN (BatchNo (None, 56, 56, 48)   192         feature_projection0[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_2 (Bilinear (None, 56, 56, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 56, 56, 48)   0           feature_projection0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 304)  0           bilinear_upsampling_2[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise (Depthw (None, 56, 56, 304)  2736        concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise_BN (Bat (None, 56, 56, 304)  1216        decoder_conv0_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 56, 56, 304)  0           decoder_conv0_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise (Conv2D (None, 56, 56, 256)  77824       activation_78[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_BN (Bat (None, 56, 56, 256)  1024        decoder_conv0_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 56, 56, 256)  0           decoder_conv0_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise (Depthw (None, 56, 56, 256)  2304        activation_79[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise_BN (Bat (None, 56, 56, 256)  1024        decoder_conv1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 56, 56, 256)  0           decoder_conv1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise (Conv2D (None, 56, 56, 256)  65536       activation_80[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_BN (Bat (None, 56, 56, 256)  1024        decoder_conv1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 56, 56, 256)  0           decoder_conv1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 56, 56, 23)   5911        activation_81[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_3 (Bilinear (None, 224, 224, 23) 0           custom_logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 224, 224, 23) 0           bilinear_upsampling_3[0][0]
# ==================================================================================================
# Total params: 41,258,727
# Trainable params: 41,055,927
# Non-trainable params: 202,800
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(generator=generateData(16, True), steps_per_epoch=440, epochs=20,
                                  validation_data=generateData(16, False), validation_steps=45, callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 440/440 [==============================] - 311s 706ms/step - loss: 0.1044 - acc: 0.9605 - val_loss: 0.4182 - val_acc: 0.8867
#
# Epoch 00001: acc improved from -inf to 0.96045, saving model to ./models/deeplab_2.hdf5
# Epoch 2/20
# 440/440 [==============================] - 245s 556ms/step - loss: 0.1040 - acc: 0.9605 - val_loss: 0.3234 - val_acc: 0.9106
#
# Epoch 00002: acc improved from 0.96045 to 0.96054, saving model to ./models/deeplab_2.hdf5
# Epoch 3/20
# 440/440 [==============================] - 232s 528ms/step - loss: 0.1081 - acc: 0.9599 - val_loss: 0.2039 - val_acc: 0.9326
#
# Epoch 00003: acc did not improve from 0.96054
# Epoch 4/20
# 440/440 [==============================] - 231s 524ms/step - loss: 0.0950 - acc: 0.9639 - val_loss: 0.3832 - val_acc: 0.8932
#
# Epoch 00004: acc improved from 0.96054 to 0.96391, saving model to ./models/deeplab_2.hdf5
# Epoch 5/20
# 440/440 [==============================] - 233s 529ms/step - loss: 0.0982 - acc: 0.9626 - val_loss: 0.3071 - val_acc: 0.9098
#
# Epoch 00005: acc did not improve from 0.96391
# Epoch 6/20
# 440/440 [==============================] - 232s 527ms/step - loss: 0.0926 - acc: 0.9644 - val_loss: 0.1801 - val_acc: 0.9396
#
# Epoch 00006: acc improved from 0.96391 to 0.96438, saving model to ./models/deeplab_2.hdf5
# Epoch 7/20
# 440/440 [==============================] - 230s 522ms/step - loss: 0.0964 - acc: 0.9634 - val_loss: 0.2880 - val_acc: 0.9124
#
# Epoch 00007: acc did not improve from 0.96438
# Epoch 8/20
# 440/440 [==============================] - 230s 524ms/step - loss: 0.0873 - acc: 0.9663 - val_loss: 0.1690 - val_acc: 0.9422
#
# Epoch 00008: acc improved from 0.96438 to 0.96628, saving model to ./models/deeplab_2.hdf5
# Epoch 9/20
# 440/440 [==============================] - 241s 547ms/step - loss: 0.0888 - acc: 0.9658 - val_loss: 0.2105 - val_acc: 0.9322
#
# Epoch 00009: acc did not improve from 0.96628
# Epoch 10/20
# 440/440 [==============================] - 243s 553ms/step - loss: 0.0852 - acc: 0.9669 - val_loss: 0.2067 - val_acc: 0.9342
#
# Epoch 00010: acc improved from 0.96628 to 0.96693, saving model to ./models/deeplab_2.hdf5
# Epoch 11/20
# 440/440 [==============================] - 242s 551ms/step - loss: 0.0851 - acc: 0.9671 - val_loss: 0.1825 - val_acc: 0.9404
#
# Epoch 00011: acc improved from 0.96693 to 0.96709, saving model to ./models/deeplab_2.hdf5
# Epoch 12/20
# 440/440 [==============================] - 249s 566ms/step - loss: 0.0849 - acc: 0.9677 - val_loss: 0.1830 - val_acc: 0.9391
#
# Epoch 00012: acc improved from 0.96709 to 0.96768, saving model to ./models/deeplab_2.hdf5
# Epoch 13/20
# 440/440 [==============================] - 246s 560ms/step - loss: 0.0804 - acc: 0.9687 - val_loss: 0.1962 - val_acc: 0.9371
#
# Epoch 00013: acc improved from 0.96768 to 0.96867, saving model to ./models/deeplab_2.hdf5
# Epoch 14/20
# 440/440 [==============================] - 249s 565ms/step - loss: 0.0788 - acc: 0.9693 - val_loss: 0.2341 - val_acc: 0.9315
#
# Epoch 00014: acc improved from 0.96867 to 0.96926, saving model to ./models/deeplab_2.hdf5
# Epoch 15/20
# 440/440 [==============================] - 248s 564ms/step - loss: 0.0780 - acc: 0.9695 - val_loss: 0.1710 - val_acc: 0.9436
#
# Epoch 00015: acc improved from 0.96926 to 0.96948, saving model to ./models/deeplab_2.hdf5
# Epoch 16/20
# 440/440 [==============================] - 247s 561ms/step - loss: 0.0780 - acc: 0.9700 - val_loss: 0.2085 - val_acc: 0.9346
#
# Epoch 00016: acc improved from 0.96948 to 0.97002, saving model to ./models/deeplab_2.hdf5
# Epoch 17/20
# 440/440 [==============================] - 246s 559ms/step - loss: 0.0740 - acc: 0.9709 - val_loss: 0.1535 - val_acc: 0.9479
#
# Epoch 00017: acc improved from 0.97002 to 0.97090, saving model to ./models/deeplab_2.hdf5
# Epoch 18/20
# 440/440 [==============================] - 247s 561ms/step - loss: 0.0758 - acc: 0.9706 - val_loss: 0.1816 - val_acc: 0.9404
#
# Epoch 00018: acc did not improve from 0.97090
# Epoch 19/20
# 440/440 [==============================] - 242s 551ms/step - loss: 0.0710 - acc: 0.9720 - val_loss: 0.1726 - val_acc: 0.9455
#
# Epoch 00019: acc improved from 0.97090 to 0.97200, saving model to ./models/deeplab_2.hdf5
# Epoch 20/20
# 440/440 [==============================] - 239s 543ms/step - loss: 0.0720 - acc: 0.9717 - val_loss: 0.1652 - val_acc: 0.9460
#
# Epoch 00020: acc did not improve from 0.97200
