# %% [markdown]
# #### 1.opencv

# %%
import  cv2

# %%
# 读取图片,图片的numpy是以BGR排列，不是以RGB排列的方式
#用opencv读取图片的时候，如果图片不存在，并不会报错
x1=cv2.imread('./test_img.jpg')

# %% [markdown]
# 返回的数组为(高，宽，channels)

# %%
x1.shape
# Out:
# (480, 640, 3)

# %%
#将数组保存为图像
cv2.imwrite('x1.jpg',x1)
# Out:
# True

# %% [markdown]
# #### 2. keras.preprocessing.image

# %%
from keras.preprocessing import image
#读取图片，图片的numpy是以RGB的形式排列
x2=image.load_img('test_img.jpg')
x2=image.img_to_array(x2)

# %%
#(高，宽，channels)
x2.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# #### 3.PIL.Image

# %%
from PIL import Image
import numpy as np
from skimage import io
x3=Image.open('/input0/label/2008_003252.png')

# %%
x3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x375 at 0x7FF9DC6F3400>

# %%
#存储图片
x3=np.array(x3)
x3=Image.fromarray(x3)
x3.save('x3.jpg')

# %%
#PIL在读取mask的时候有一个坑，当然可能是模式选择的问题,还有一个坑是PIL在做resize的时候会改变原来的像素颜色，最好用opencv进行resize
x3=np.array(x3)
print(x3.shape)
io.imshow(x3)
# Out:
# (375, 500)

# %% [markdown]
# #### 4.scipy.misc

# %%
from scipy import misc
x4=misc.imread('test_img.jpg')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
#(高，宽，channels)
x4.shape
# Out:
# (480, 640, 3)

# %%
#保存图像
misc.imsave('x4.jpg',x4)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %% [markdown]
# #### 5. skimage.io

# %%
from skimage import io

# %%
#skimage.io可以轻松读取tif图
x5=io.imread('test_img.jpg')

# %%
#(高，宽，channels)
x5.shape
# Out:
# (480, 640, 3)

# %%
#显示图像
io.imshow(x5)

# %%
io.imsave('x5.jpg',x5)
